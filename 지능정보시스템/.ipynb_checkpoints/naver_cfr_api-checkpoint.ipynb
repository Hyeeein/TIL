# %% [markdown]
# ## 2022년 12월 7일 실습 (1)
#
# `인천대학교 경제학과 201900740 박혜인`

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import sys
import requests
client_id = "RGdtUWOtQmyNw9_HPSdT"
client_secret = "4jkUTNCNea"
# url = "https://openapi.naver.com/v1/vision/face"     # 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
files = {'image': open('유재석1.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":547,"height":832},"faceCount":1},"faces":[{"celebrity":{"value":"유재석","confidence":1.0}}]}

# %%
import os
import sys
import requests
client_id = "RGdtUWOtQmyNw9_HPSdT"
client_secret = "4jkUTNCNea"
url = "https://openapi.naver.com/v1/vision/face"     # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
files = {'image': open('유재석1.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":547,"height":832},"faceCount":1},"faces":[{"roi":{"x":141,"y":113,"width":181,"height":181},"landmark":{"leftEye":{"x":187,"y":159},"rightEye":{"x":271,"y":149},"nose":{"x":243,"y":210},"leftMouth":{"x":207,"y":264},"rightMouth":{"x":281,"y":251}},"gender":{"value":"male","confidence":0.999933},"age":{"value":"46~50","confidence":0.593986},"emotion":{"value":"neutral","confidence":0.999994},"pose":{"value":"frontal_face","confidence":0.996732}}]}

# %% [markdown]
# 유재석 사진으로 유명인 얼굴인식을 했을 때, 유재석으로 결과가 잘 나왔다.
#
# 얼굴 감지를 했을 때, 눈, 코, 입 위치를 좌표로 나타냈고, 인식된 성별은 male로 정확하게 탐지했다. 그리고 감지된 얼굴의 나이를 추정한 정보가 실제 정보와 조금 다르지만, 사진을 찍었을 때의 시점으로 생각하면 옳은 결과가 나왔을 확률도 있다. 감지된 얼굴의 표정은 무표정이고, 포즈는 정면을 보고 있다.
