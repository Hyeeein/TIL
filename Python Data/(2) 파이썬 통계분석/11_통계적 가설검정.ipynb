# %% [markdown]
# # Chapter 11. 통계적 가설검정

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %precision 3
np.random.seed(1111)

# %%
df = pd.read_csv('C:/TIL/Python_data/data/ch11_potato.csv')
sample = np.array(df['무게'])
sample
# Out:
# array([122.02, 131.73, 130.6 , 131.82, 132.05, 126.12, 124.43, 132.89,
#        122.79, 129.95, 126.14, 134.45, 127.64, 125.68])

# %%
# 표본 평균
s_mean = np.mean(sample)
s_mean
# Out:
# 128.4507142857143

# %% [markdown]
# ## 11.1 통계적 가설검정

# %% [markdown]
# * 통계적 가설검정 : 모집단의 모수에 관한 두 가지 가설을 세우고, 표본으로부터 계산되는 통계량을 이용하여 어느 가설이 옳은지 판단하는 통계적 방법

# %%
rv = stats.norm(130, np.sqrt(9/14))
rv.isf(0.95)
# Out:
# 128.68118313069039

# %% [markdown]
# ![image.png](attachment:image.png)
