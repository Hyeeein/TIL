# %%
import tensorflow as tf
import matplotlib.pyplot as plt

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# C:\Users\phi49\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## 머신러닝 문제 해결 방법
#
# 1. 훈련 데이터 얻기
# 2. 모델 정의
# 3. 손실 함수 정의
# 4. 훈련 데이터를 실행하여 이상적인 값에서 손실을 계산
# 5. 손실에 대한 기울기를 계산하고, 최적화 프로그램을 사용하여 데이터에 맞게 변수 조정
# 6. 결과 평가
#
# 여기에서는 W(가중치) 및 b(바이어스)의 두 가지 변수가 있는 간단한 선형모델 f(x) = x * W + b 개발

# %% [markdown]
# ## 데이터

# %% [markdown]
# * 지도 학습 : 입력(일반적으로 x로 표시)과 출력(y로 표시, 레이블이라고도 함)을 사용
#     - 목표는 입력에서 출력 값을 예측할 수 있도록 쌍을 이룬 입력과 출력에서 학습하는 것
#
#
# * TensorFlow에서 데이터의 각 입력은 거의 항상 텐서로 표현되며, 종종 벡터 (출력도 텐서)
#
#
# * 아래 예시는 선을 따라 점에 가우시안(정규분포) 노이즈를 추가하여 합성된 데이터
#
#
# * 텐서는 일반적으로 배치 또는 입력과 출력이 함께 쌓인 그룹의 형태로 수집
#     - 일괄 처리는 몇 가지 훈련 이점을 제공할 수 있으며, 가속기 및 벡터화된 계산에서 잘 동작
#     - 데이터세트가 얼마나 작은지 고려할 때, 전체 데이터세트를 단일 배치로 처리 가능

# %%
# The actual line
TRUE_W = 3.0
TRUE_B = 2.0

NUM_EXAMPLES = 201

# A vector of random x values
x = tf.linspace(-2,2, NUM_EXAMPLES)  # 지정되 축에 따라 균일한 간격으로 나누는 숫자의 시퀀스
x = tf.cast(x, tf.float32)           # tf.cast : 텐서의 형을 변환

def f(x):
    return x * TRUE_W + TRUE_B

# Generate some noise
noise = tf.random.normal(shape=[NUM_EXAMPLES])

# Calculate y
y = f(x) + noise

# %%
# Plot all the data
plt.plot(x, y, '.')
plt.show()

# %% [markdown]
# ## 모델 정의하기

# %% [markdown]
# `tf.Variable` : 모델의 모든 가중치를 나타냄. 값을 저장하고 필요에 따라 텐서 형식으로 제공
#
# `tf.Module` : 변수와 계산을 캡슐화 함. 모든 Python 객체를 사용할 수 있고, 이것을 사용해 쉽게 저장 가능

# %%
class MyModel(tf.Module):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # 가중치는 5.0, 편향은 0.0으로 초기화 (여기선 랜덤으로 초기화)
        self.w = tf.Variable(5.0)
        self.b = tf.Variable(0.0)

    def __call__(self, x):
        return self.w * x + self.b

model = MyModel()

# List the variables tf.modules's built-in variable aggregation.
print("Variables:", model.variables)

# Verify the model works
assert model(3.0).numpy() == 15.0
# Out:
# Variables: (<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>, <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.0>)

# %% [markdown]
# ### 손실 함수 정의하기

# %% [markdown]
# * 손실함수 : 주어진 입력에 대한 모델의 출력이 목표 출력과 얼마나 잘 일치하는지 측정
#
#
# * 목표 : 훈련 중에 이러한 차이를 최소화 하는 것이고, "평균 제곱" 오류라고도 하는 표준 L2 손실을 정의

# %%
# 전체 배치 단계를 하는 동안 단일 손실 값을 계산
def loss(target_y, predicted_y):
    return tf.reduce_mean(tf.square(target_y - predicted_y))

# %% [markdown]
# * 모델 훈련 전, 모델 예측을 빨강 / 훈련 데이터를 파랑으로 플롯 => 손실값 시각화 가능

# %%
plt.plot(x, y, '.', label="Data")
plt.plot(x, f(x), label="Ground truth")
plt.plot(x, model(x), label="Predictions")
plt.legend()
plt.show()

print("Current loss: %1.6f" % loss(y, model(x)).numpy())
# Out:
# Current loss: 10.660592

# %% [markdown]
# ### 훈련 루프 정의하기

# %% [markdown]
# 훈련 루프는 순서대로 3가지 작업을 반복적으로 수행
#
#
# - 모델을 통해 입력 배치를 전송하여 출력 생성
#
#
# - 출력을 출력(또는 레이블)과 비교하여 손실 계산
#
#
# - 그래디언트 테이프를 사용하여 그래디언트 찾기
#
#
# - 해당 그래디언트로 변수 최적화

# %% [markdown]
# `tf.keras.optimizers`에서 캡처되는 경사 하강법 체계에는 다양한 변형이 있음
#
# -> 여기서는 기본적인 수학만 구현, 자동 미분을 위한 `tf.GradientTape` 및 감소를 위한 `tf.assign_sub`의 도움

# %%
# Given a callable model, inputs, outputs, and a learning rate...
def train(model, x, y, learning_rate):

    with tf.GradientTape() as t:
        # Trainable variables are automatically tracked by GradientTape
        current_loss = loss(y, model(x))

    # Use GradientTape to calculate the gradients with respect to W and b
    dw, db = t.gradient(current_loss, [model.w, model.b])

    # Subtract the gradient scaled by the learning rate
    model.w.assign_sub(learning_rate * dw)
    model.b.assign_sub(learning_rate * db)

# %% [markdown]
# 훈련 루프를 통해 x 및 y의 같은 배치를 보내고 W 및 b가 발전하는 모양을 확인

# %%
model = MyModel()

# Collect the history of W-values and b-values to plot later
weights = []
biases = []
epochs = range(10)

# Define a training loop
def report(model, loss):
    return f"W = {model.w.numpy():1.2f}, b = {model.b.numpy():1.2f}, loss={loss:2.5f}"


def training_loop(model, x, y):

    for epoch in epochs:
        # Update the model with the single giant batch
        train(model, x, y, learning_rate=0.1)

        # Track this before I update
        weights.append(model.w.numpy())
        biases.append(model.b.numpy())
        current_loss = loss(y, model(x))

        print(f"Epoch {epoch:2d}:")
        print("    ", report(model, current_loss))

# %% [markdown]
# 훈련 수행

# %%
current_loss = loss(y, model(x))

print(f"Starting:")
print("    ", report(model, current_loss))

training_loop(model, x, y)
# Out:
# Starting:
#      W = 5.00, b = 0.00, loss=10.66059
# Epoch  0:
#      W = 4.45, b = 0.40, loss=6.59942
# Epoch  1:
#      W = 4.05, b = 0.72, loss=4.27937
# Epoch  2:
#      W = 3.75, b = 0.97, loss=2.94356
# Epoch  3:
#      W = 3.54, b = 1.18, loss=2.16819
# Epoch  4:
#      W = 3.38, b = 1.34, loss=1.71442
# Epoch  5:
#      W = 3.26, b = 1.47, loss=1.44668
# Epoch  6:
#      W = 3.18, b = 1.58, loss=1.28744
# Epoch  7:
#      W = 3.12, b = 1.66, loss=1.19198
# Epoch  8:
#      W = 3.07, b = 1.73, loss=1.13434
# Epoch  9:
#      W = 3.04, b = 1.78, loss=1.09929

# %% [markdown]
# 시간이 지남에 따른 가중치 전개 양상 표시

# %%
plt.plot(epochs, weights, label='Weights', color=colors[0])
plt.plot(epochs, [TRUE_W] * len(epochs), '--',
         label = "True weight", color=colors[0])

plt.plot(epochs, biases, label='bias', color=colors[1])
plt.plot(epochs, [TRUE_B] * len(epochs), "--",
         label="True bias", color=colors[1])

plt.legend()
plt.show()

# %% [markdown]
# 훈련된 모델 성능 시각화

# %%
plt.plot(x, y, '.', label="Data")
plt.plot(x, f(x), label="Ground truth")
plt.plot(x, model(x), label="Predictions")
plt.legend()
plt.show()

print("Current loss: %1.6f" % loss(model(x), y).numpy())
# Out:
# Current loss: 1.099293

# %% [markdown]
# ## [번외] Keras를 사용한 경우

# %% [markdown]
# `tf.keras.Model` : 비슷해 보이지만, 궁극적으로 모듈에서 상속함

# %%
class MyModelKeras(tf.keras.Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # Initialize the weights to `5.0` and the bias to `0.0`
        # In practice, these should be randomly initialized
        self.w = tf.Variable(5.0)
        self.b = tf.Variable(0.0)

    def call(self, x):
        return self.w * x + self.b

keras_model = MyModelKeras()

# Reuse the training loop with a Keras model
training_loop(keras_model, x, y)

# You can also save a checkpoint using Keras's built-in support
keras_model.save_weights("my_checkpoint")
# Out:
# Epoch  0:
#      W = 4.45, b = 0.40, loss=6.59942
# Epoch  1:
#      W = 4.05, b = 0.72, loss=4.27937
# Epoch  2:
#      W = 3.75, b = 0.97, loss=2.94356
# Epoch  3:
#      W = 3.54, b = 1.18, loss=2.16819
# Epoch  4:
#      W = 3.38, b = 1.34, loss=1.71442
# Epoch  5:
#      W = 3.26, b = 1.47, loss=1.44668
# Epoch  6:
#      W = 3.18, b = 1.58, loss=1.28744
# Epoch  7:
#      W = 3.12, b = 1.66, loss=1.19198
# Epoch  8:
#      W = 3.07, b = 1.73, loss=1.13434
# Epoch  9:
#      W = 3.04, b = 1.78, loss=1.09929

# %% [markdown]
# 모델 생성 시, 새로운 훈련 루프를 작성하는 대신, Keras의 내장 기능을 바로 가기로 사용할 수 있음
#
# Python 훈련 루프를 작성하거나 디버그하지 않으려는 경우 유용함
#
# * `model.compile()`을 사용하여 매개변수를 설정하고, `model.fit()`을 사용하여 훈련해야 함
#
#
# * L2손실 및 경사 하강법의 Keras 구현을 바로 가기로 사용하면 코드가 적을 수 있음

# %%
keras_model = MyModelKeras()

# compile sets the training parameters
keras_model.compile(
    # By default, fit() uses tf.function().  You can
    # turn that off for debugging, but it is on now.
    run_eagerly=False,

    # Using a built-in optimizer, configuring as an object
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),

    # Keras comes with built-in MSE error
    # However, you could use the loss function
    # defined above
    loss=tf.keras.losses.mean_squared_error,
)

# %% [markdown]
# Keras`fit` 배치 데이터 또는 전체 데이터 세트는 NumPy 배열로 예상 (배치로 분할, 기본 배치는 32)
#
# 이 경우, 손으로 쓴 루프의 동작과 일치시키려면 x를 크기 1000의 단일 배치로 전달해야 함

# %%
print(x.shape[0])
keras_model.fit(x, y, epochs=10, batch_size=1000)
# Out:
# 201
# Epoch 1/10
# 1/1 [==============================] - 0s 281ms/step - loss: 10.6606
# Epoch 2/10
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5994
# Epoch 3/10
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2794
# Epoch 4/10
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9436
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1682
# Epoch 6/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7144
# Epoch 7/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4467
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2874
# Epoch 9/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1920
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1343

# %% [markdown]
# Keras는 훈련 전이 아닌 훈련 후 손실을 출력 -> 첫 번째 손실이 더 낮게 나타나지만, 그렇지 않으면 본질적으로 같은 훈련 성능을 보여줌
