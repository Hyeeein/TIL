# %% [markdown]
# ## 인구 공공데이터 살펴보기
#
#
# * 혹시 한글이 깨져보인다면?
#     - 파일 -> 다른 이름으로 저장 -> 파일 인코딩을 UTF-8로 바꾸고, 파일 형식을 모든 파일로 바꿔 저장
#
#
# * 헤더 살펴보기

# %%
import csv

f = open('incheon_population.csv', 'r')
data = csv.reader(f)
header = next(data)
print(header)
# Out:
# ['행정구역', '2021년08월_남_총인구수', '2021년08월_남_연령구간인구수', '2021년08월_남_0세', '2021년08월_남_1세', '2021년08월_남_2세', '2021년08월_남_3세', '2021년08월_남_4세', '2021년08월_남_5세', '2021년08월_남_6세', '2021년08월_남_7세', '2021년08월_남_8세', '2021년08월_남_9세', '2021년08월_남_10세', '2021년08월_남_11세', '2021년08월_남_12세', '2021년08월_남_13세', '2021년08월_남_14세', '2021년08월_남_15세', '2021년08월_남_16세', '2021년08월_남_17세', '2021년08월_남_18세', '2021년08월_남_19세', '2021년08월_남_20세', '2021년08월_남_21세', '2021년08월_남_22세', '2021년08월_남_23세', '2021년08월_남_24세', '2021년08월_남_25세', '2021년08월_남_26세', '2021년08월_남_27세', '2021년08월_남_28세', '2021년08월_남_29세', '2021년08월_남_30세', '2021년08월_남_31세', '2021년08월_남_32세', '2021년08월_남_33세', '2021년08월_남_34세', '2021년08월_남_35세', '2021년08월_남_36세', '2021년08월_남_37세', '2021년08월_남_38세', '2021년08월_남_39세', '2021년08월_남_40세', '2021년08월_남_41세', '2021년08월_남_42세', '2021년08월_남_43세', '2021년08월_남_44세', '2021년08월_남_45세', '2021년08월_남_46세', '2021년08월_남_47세', '2021년08월_남_48세', '2021년08월_남_49세', '2021년08월_남_50세', '2021년08월_남_51세', '2021년08월_남_52세', '2021년08월_남_53세', '2021년08월_남_54세', '2021년08월_남_55세', '2021년08월_남_56세', '2021년08월_남_57세', '2021년08월_남_58세', '2021년08월_남_59세', '2021년08월_남_60세', '2021년08월_남_61세', '2021년08월_남_62세', '2021년08월_남_63세', '2021년08월_남_64세', '2021년08월_남_65세', '2021년08월_남_66세', '2021년08월_남_67세', '2021년08월_남_68세', '2021년08월_남_69세', '2021년08월_남_70세', '2021년08월_남_71세', '2021년08월_남_72세', '2021년08월_남_73세', '2021년08월_남_74세', '2021년08월_남_75세', '2021년08월_남_76세', '2021년08월_남_77세', '2021년08월_남_78세', '2021년08월_남_79세', '2021년08월_남_80세', '2021년08월_남_81세', '2021년08월_남_82세', '2021년08월_남_83세', '2021년08월_남_84세', '2021년08월_남_85세', '2021년08월_남_86세', '2021년08월_남_87세', '2021년08월_남_88세', '2021년08월_남_89세', '2021년08월_남_90세', '2021년08월_남_91세', '2021년08월_남_92세', '2021년08월_남_93세', '2021년08월_남_94세', '2021년08월_남_95세', '2021년08월_남_96세', '2021년08월_남_97세', '2021년08월_남_98세', '2021년08월_남_99세', '2021년08월_남_100세 이상', '2021년08월_여_총인구수', '2021년08월_여_연령구간인구수', '2021년08월_여_0세', '2021년08월_여_1세', '2021년08월_여_2세', '2021년08월_여_3세', '2021년08월_여_4세', '2021년08월_여_5세', '2021년08월_여_6세', '2021년08월_여_7세', '2021년08월_여_8세', '2021년08월_여_9세', '2021년08월_여_10세', '2021년08월_여_11세', '2021년08월_여_12세', '2021년08월_여_13세', '2021년08월_여_14세', '2021년08월_여_15세', '2021년08월_여_16세', '2021년08월_여_17세', '2021년08월_여_18세', '2021년08월_여_19세', '2021년08월_여_20세', '2021년08월_여_21세', '2021년08월_여_22세', '2021년08월_여_23세', '2021년08월_여_24세', '2021년08월_여_25세', '2021년08월_여_26세', '2021년08월_여_27세', '2021년08월_여_28세', '2021년08월_여_29세', '2021년08월_여_30세', '2021년08월_여_31세', '2021년08월_여_32세', '2021년08월_여_33세', '2021년08월_여_34세', '2021년08월_여_35세', '2021년08월_여_36세', '2021년08월_여_37세', '2021년08월_여_38세', '2021년08월_여_39세', '2021년08월_여_40세', '2021년08월_여_41세', '2021년08월_여_42세', '2021년08월_여_43세', '2021년08월_여_44세', '2021년08월_여_45세', '2021년08월_여_46세', '2021년08월_여_47세', '2021년08월_여_48세', '2021년08월_여_49세', '2021년08월_여_50세', '2021년08월_여_51세', '2021년08월_여_52세', '2021년08월_여_53세', '2021년08월_여_54세', '2021년08월_여_55세', '2021년08월_여_56세', '2021년08월_여_57세', '2021년08월_여_58세', '2021년08월_여_59세', '2021년08월_여_60세', '2021년08월_여_61세', '2021년08월_여_62세', '2021년08월_여_63세', '2021년08월_여_64세', '2021년08월_여_65세', '2021년08월_여_66세', '2021년08월_여_67세', '2021년08월_여_68세', '2021년08월_여_69세', '2021년08월_여_70세', '2021년08월_여_71세', '2021년08월_여_72세', '2021년08월_여_73세', '2021년08월_여_74세', '2021년08월_여_75세', '2021년08월_여_76세', '2021년08월_여_77세', '2021년08월_여_78세', '2021년08월_여_79세', '2021년08월_여_80세', '2021년08월_여_81세', '2021년08월_여_82세', '2021년08월_여_83세', '2021년08월_여_84세', '2021년08월_여_85세', '2021년08월_여_86세', '2021년08월_여_87세', '2021년08월_여_88세', '2021년08월_여_89세', '2021년08월_여_90세', '2021년08월_여_91세', '2021년08월_여_92세', '2021년08월_여_93세', '2021년08월_여_94세', '2021년08월_여_95세', '2021년08월_여_96세', '2021년08월_여_97세', '2021년08월_여_98세', '2021년08월_여_99세', '2021년08월_여_100세 이상']

# %% [markdown]
# * 위의 리스트에서
#
#
#     - '2021년08월_남_0세'의 index는? 3
#     - '2021년08월_남_1세'의 index는? 4
#     - '2021년08월_남_100세 이상'의 index는? 103
#
#     - '2021년08월_여_0세'의 index는? 106
#     - '2021년08월_여_1세'의 index는? 107
#     - '2021년08월_여_100세 이상'의 index는? 206
#
# * 우리의 관심사는 남성(3 ~ 103), 여성(106 ~ 206)

# %% [markdown]
# ## 우리 동네 인구 구조 시각화 절차

# %% [markdown]
# 1. 인구 데이터 파일을 읽어온다.
#
#
# 2. 전체 데이터에서 한 줄씩 반복해서 읽어온다.
#
#
# 3. 시각화 대상 데이터를 선별한다.
#
#
# 4. 0세부터 100세 이상까지의 인구수를 순서대로 지정한다.
#
#
# 5. 저장된 연령별 인구수 데이터를 시각화한다.

# %% [markdown]
# ### 1. 데이터 읽어오기
#
#
# * in 연산자를 활용해 우리 동네의 이름이 포함된 지역명 찾기
#     - 특정한 문자열 안에 찾고자 하는 문자열이 있는지 확인
#
#
# * 리스트 슬라이싱(slicing)
#     - 리스트의 데이터를 일부 자르는 방법 (인덱스가 각 값의 앞쪽에 붙어있다고 생각)
#     - 사용 예: a[start:end+1]
#
#
# * 우리 동네 연령별 남성 인구수 출력
#
#
# * 우리 동네 남성 연령별 인구수 male 리스트에 저장
#
#
# * 문자 데이터를 정수로 변환

# %%
import csv

f = open('incheon_population.csv', 'r')
data = csv.reader(f)

male = []
for row in data:
    if '송도1동' in row[0]:
        for i in row[3:104]:
            # print(i)
            male.append(int(i))

print(male)
f.close()
# Out:
# [75, 108, 129, 125, 151, 163, 184, 199, 210, 232, 264, 252, 262, 325, 313, 221, 279, 280, 281, 341, 348, 330, 339, 338, 314, 313, 303, 316, 314, 308, 257, 230, 181, 189, 174, 200, 177, 209, 213, 238, 258, 277, 295, 251, 279, 265, 344, 352, 339, 379, 366, 366, 353, 347, 293, 299, 309, 269, 298, 270, 265, 267, 251, 209, 198, 165, 175, 131, 98, 143, 48, 87, 75, 59, 78, 49, 47, 42, 45, 46, 41, 34, 27, 20, 23, 14, 9, 14, 12, 2, 3, 6, 2, 9, 3, 1, 1, 0, 0, 0, 0]

# %% [markdown]
# ### 2. 우리 동네 남성 연령별 인구수 데이터 시각화
#
# * 격자 무늬 스타일 지정하기
